# %% [markdown]
# <a href="https://colab.research.google.com/github/Patrick-Setubal/Data_Science_Analytics/blob/main/Project/VideoGameSales/VideoGameSales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Problem definition

# %% [markdown]
# The aim of this project, using the **Video Game Sales** dataset, is to conduct exploratory analysis to gain a deeper understanding of the data, identify patterns, perform data cleaning, and calculate key performance indicators (KPIs). Subsequently, a dashboard will be created to visualize the insights discovered.
#
# **Fields include in dataset:**
# - Rank - Ranking of overall sales
# - Name - The games name
# - Platform - Platform of the games release (i.e. PC,PS4, etc.)
# - Year - Year of the game's release
# - Genre - Genre of the game
# - Publisher - Publisher of the game
# - NA_Sales - Sales in North America (in millions)
# - EU_Sales - Sales in Europe (in millions)
# - JP_Sales - Sales in Japan (in millions)
# - Other_Sales - Sales in the rest of the world (in millions)
# - Global_Sales - Total worldwide sales.
#
# Number of columns 11 and 16598 rows
# Link: https://www.kaggle.com/datasets/gregorut/videogamesales

# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# Get dataset
link_dataset = 'https://raw.githubusercontent.com/Patrick-Setubal/Data_Science_Analytics/main/Project/VideoGameSales/vgsales.csv'
df = pd.read_csv(link_dataset, sep=',')
display(df.head())
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # Exploratory analysis

# %%
print("Describe")
display(df.describe())
print("Info")
display(df.info())
# Out:
# Describe
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# ...

# %% [markdown]
# - There are some empty fields
# - The year field is not int

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Check the correlation of numeric fields
numeric_cols = ['Rank','Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="RdYlGn")
# Out:
# <Axes: >

# %% [markdown]
# - Sales have a positive correlation regardless of location
# - The year has no correlation with sales

# %%
df.plot(kind='density', subplots=True, sharex=False, layout=(4,2), figsize=(10,10))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# Check distribution of values filled with zero

# %%
sns.heatmap(df==0, cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# varificar campos string
# repetição dos valores
# quantos valores
# duplicidades
